# %% [markdown]
# ## Combine different user features into 1D feature vectors for further use

# %% [markdown]
# ### Load all users

# %%
import pandas as pd

# %%
users = pd.read_csv("../dataset/v1/users.csv")

display(users.head())
print(users.shape)
# Out:
#    Unnamed: 0                    id             login       username
# 0           0  MDQ6VXNlcjI0MTEzOA==          karpathy         Andrej  \
# 1           1  MDQ6VXNlcjEyNzk2MDk=        llSourcell    Siraj Raval
# 2           2  MDQ6VXNlcjM5NzE3MDk5  WebDevSimplified            NaN
# 3           3  MDQ6VXNlcjU1NTA4NTA=      bradtraversy  Brad Traversy
# 4           4  MDQ6VXNlcjQ5OTU1MA==         yyx990803       Evan You
#
#             company                                                bio
# 0               NaN  I like to train Deep Neural Nets on large data...  \
# 1               NaN  subscribe to my youtube channel! \nwww.youtube...
# 2  WebDevSimplified                                                NaN
# 3    Traversy Media  Full stack web developer and online instructor...
# 4             vuejs                                                NaN
#
#             location                      email
# 0           Stanford  andrej.karpathy@gmail.com  \
# ...

# %% [markdown]
# ### Load user bio features

# %%
import pickle
with open("../dataset/v1/bio_embeddings.pkl", "rb") as f:
    bio_embeddings = pickle.load(f)

print("print first user's bio embedding for example:")
print(bio_embeddings["MDQ6VXNlcjI0MTEzOA=="])
print(f"shape of a user's bio embedding: {bio_embeddings['MDQ6VXNlcjI0MTEzOA=='].shape}")
# Out:
# print first user's bio embedding for example:
# [-7.24301338e-02 -9.74173695e-02  4.42190319e-02  8.45280942e-03
#   3.14934435e-03 -5.80759160e-03 -3.52965761e-03 -3.16528231e-02
#  -3.45209055e-02 -8.21667239e-02 -4.37746458e-02  6.32571682e-05
#  -8.16962346e-02  2.77713896e-03 -7.39563033e-02  4.87638786e-02
#   3.47048417e-02  1.10894844e-01 -1.00478917e-01 -6.62319139e-02
#  -4.50464264e-02  2.51754746e-02  2.92875730e-02 -4.01255973e-02
#   1.74698997e-02  2.44309902e-02 -1.80077925e-02 -7.57417753e-02
#   1.96842663e-02 -3.50954011e-02 -2.95555592e-02 -4.69376817e-02
#  -3.95247824e-02  1.05592616e-01 -4.85376343e-02  6.00923747e-02
#  -6.54604211e-02 -1.57649126e-02  2.99909580e-02 -8.35975516e-04
#   3.59552391e-02  4.40961309e-02  4.45016399e-02 -2.70841061e-03
#   8.43554512e-02 -2.66490001e-02  3.81104350e-02 -5.11485450e-02
#   1.17382273e-01  6.29521534e-02 -5.50713912e-02 -1.53917670e-02
#  -1.53100323e-02  4.14079726e-02  2.50024516e-02 -4.32606116e-02
# ...
