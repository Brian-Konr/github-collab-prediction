# %%
import pandas as pd
import numpy as np
import queue
from github import Github
from gql import gql, Client
from gql.transport.aiohttp import AIOHTTPTransport
import json
from datetime import datetime
from time import sleep

# %%
top_users = pd.read_csv('./data/top-users.csv')

# %%
github_token = ""
# Select your transport with a defined url endpoint
transport = AIOHTTPTransport(url="https://api.github.com/graphql",  headers={'Authorization': 'bearer {}'.format(github_token)})

# Create a GraphQL client using the defined transport
client = Client(transport=transport, fetch_schema_from_transport=True, execute_timeout=120)

g = Github(github_token, per_page=100)

# %%
userRepoQuery = gql(
"""
    query getUserConnections($login: String!)
    {
        user(login: $login) {
            id
            name
            company
            bio
            location
            email
            followers(first: 100) {
                nodes {
                    login
                }
            }
            following(first: 100) {
                nodes {
                    login
                }
            }
            starredRepositories(first: 100) {
                nodes {
                    id
                    name
                    owner {
                        login
                    }
                    description
                    repositoryTopics(first: 10) {
                        nodes {
                            topic {
                                name
                            }
                        }
                    }
                    languages(first: 10) {
                        nodes {
                            name
                        }
                    }
                }
                edges {
                    starredAt
                }
            }
            repositoriesContributedTo(first: 10, privacy: PUBLIC, contributionTypes: [COMMIT]) {
                nodes {
                    id
                    name
                    owner {
                        login
                    }
                    description
                    repositoryTopics(first: 10) {
                        nodes {
                            topic {
                                name
                            }
                        }
                    }
                    languages(first: 10) {
                        nodes {
                            name
                        }
                    }
                }
            }
        }
    }
"""
)

# %%
L = 4 # Search Depth
NUM_SEED_USERS = 10
# SEARCH_SINCE = datetime.fromisoformat('2023-01-01')

logins = top_users['login'][:NUM_SEED_USERS]

U = [set(logins)]
R = []

searched_users = set()
info_searched_repos = set()
searched_repos = set()

fetched_users_data = []
fetched_commits_data = []
fetched_repos_data = []
fetched_contributions_data = []

for i in range(L):
    print("Search depth:", i + 1)
    U.append(set())
    R.append(set())
    print('#Users to search:', len(U[i]))
    while len(U[i]) > 0:  
        try:
            while g.rate_limiting[0] < 50:
                print("rate limit almost approached, staling...")
                sleep(10)
                g.get_rate_limit()

            cur_user = U[i].pop()
            if cur_user in searched_users:
                continue
            searched_users.add(cur_user)
            print("Searching", cur_user)
        
            res = await client.execute_async(userRepoQuery, { "login": cur_user })
            
            cur_user_repos = ["{login}/{name}".format(login=node["owner"]["login"], name=node["name"]) for node in res["user"]["repositoriesContributedTo"]["nodes"]]
            cur_user_starred_repos = [{
                "name": "{login}/{name}".format(login=node["owner"]["login"], name=node["name"]), 
                "starred_at": edge["starredAt"]
                }
                for node, edge in zip(res["user"]["starredRepositories"]["nodes"], res["user"]["starredRepositories"]["edges"])]
            
            # Store new repo information
            cur_user_repo_data = [{
                "id": node["id"],
                "name": "{login}/{name}".format(login=node["owner"]["login"], name=node["name"]),
                "description": node["description"],
                "topics": [topic_node["topic"]["name"] for topic_node in node["repositoryTopics"]["nodes"]],
                "languages": [language_node["name"] for language_node in node["languages"]["nodes"]]
            } for node in res["user"]["starredRepositories"]["nodes"] + res["user"]["repositoriesContributedTo"]["nodes"] if node["id"] not in info_searched_repos]
            info_searched_repos = info_searched_repos.union(set(repo["id"] for repo in cur_user_repo_data))

            cur_user_followers = [node["login"] for node in res["user"]["followers"]["nodes"]]
            cur_user_following = [node["login"] for node in res["user"]["following"]["nodes"]]
            fetched_users_data.append({
                    "id": res["user"]["id"],
                    "login": cur_user, 
                    "username": res["user"]["name"], 
                    "company": res["user"]["company"], 
                    "bio": res["user"]["bio"], 
                    "location": res["user"]["location"], 
                    "email": res["user"]["email"], 
                    "followers": cur_user_followers,
                    "following": cur_user_following,
                    "repos": cur_user_repos,
                    "starred_repos": cur_user_starred_repos,
                }
            )
            fetched_repos_data = fetched_repos_data + cur_user_repo_data

            # Add repos to search
            R[i] = R[i].union(set(cur_user_repos[:10]))
        except Exception as e:
            print(e)
            continue

    print('#Repos to search:', len(R[i]))
    while len(R[i]) > 0:
        try:
            while g.rate_limiting[0] < 50:
                print("rate limit almost approached, staling...")
                sleep(10)
                g.get_rate_limit()

            cur_repo = R[i].pop()
            if cur_repo in searched_repos:
                continue
            searched_repos.add(cur_repo)
            print("Searching", cur_repo)

            # Search by contributors
            contributor_objs = g.get_repo(cur_repo).get_contributors()
            contributors = [user.login for user in contributor_objs[:10] if "bot" not in user.login]
        
            cur_contributions_data = [{ "user_login": user, "repo": cur_repo } for user in contributors]
            fetched_contributions_data = fetched_contributions_data + cur_contributions_data
            U[i + 1] = U[i + 1].union(set(contributors))

        # Search by committers
        # commit_objs = g.get_repo(repo).get_commits(since=SEARCH_SINCE)
        # commits = [{
        #     "author": commit.author.login,
        #     "datetime": commit.commit.author.date,
        #     "repo": repo,
        #     "code_modified": commit.stats.total,
        # } for commit in commit_objs if commit.author]
        # committers = [commit["author"] for commit in commits if "[bot]" not in commit["author"]]
        # fetched_commits_data = fetched_commits_data + commits
        # U = U.union(set(committers))
        except Exception as e:
            print(e)
            continue
# Out:
# Search depth: 1
# #Users to search: 10
# Searching sdras
# Searching bradtraversy
# Searching diego3g
# Searching llSourcell
# Searching buckyroberts
# Searching WebDevSimplified
# Searching karpathy
# Searching yyx990803
# Searching gaearon
# Searching StephenGrider
# #Repos to search: 35
# Searching rocketseat-content/next-trpc-typescript-zod
# Searching reactjs/rfcs
# Searching thenewboston-developers/Website
# Searching rocketseat-education/masterclass-fundamentos-nestjs
# Searching babel/website
# Searching thenewboston-developers/tnbOS
# Searching vuejs/v2.cn.vuejs.org
# Searching vuejs/vue-component-compiler
# Searching facebook/react-native-website
# Searching rocketseat-education/05-design-system
# Searching reactjs/zh-hans.react.dev
# Searching vuejs/v2.vuejs.org
# Searching roginfarrer/collapsed
# Searching vuejs/jp.vuejs.org
# Searching Rocketseat/eslint-config-rocketseat
# Searching colinhacks/zod
# Searching vuejs/vue-class-component
# Searching vuejs/vue
# Searching vuejs/vue-cli
# Searching facebook/react
# Searching vuejs/vue-loader
# Searching rocketseat-content/react-storybook
# Searching Rocketseat/app-quiz
# Searching maykbrito/mini-video-me
# Searching thenewboston-developers/Core
# Searching huggingface/transformers
# Searching vuejs/vuex
# Searching facebook/react-native
# Searching reactjs/es.react.dev
# Searching Rocketseat/maratona-explorer-ticket
# Searching reactjs/react.dev
# Searching vuejs/devtools
# Searching maykbrito/fronteditorv2
# Searching kuitos
# Searching smikitky
# Searching rickhanlonii
# Searching sebmck
# Searching tesseralis
# Searching blake-newman
# Searching hzoo
# Searching vjeux
# Searching zpao
# Searching baybara-pavel
# Searching Darking360
# Searching sophiebits
# Searching finico
# Searching defcc
# #Repos to search: 535
# Searching quasarframework/vue-cli-plugin-quasar
# Searching simple-statistics/simple-statistics
# Searching Ninja-Squad/ngx-speculoos
# Searching rome/brand
# Searching DIYgod/RSSHub
# Searching slidevjs/docs-cn
# Searching q8s-io/iapetos
# Searching denoland/dotland
# Searching w3c/manifest
# Searching vue-bridge/vue-bridge
# Searching facebook/buck2
# Searching sleuth-io/sleuth-gitbook-docs
# Searching pgsql-jp/jpug-doc
# Searching ast-grep/ast-grep-vscode
# Searching koel/core
# Searching viaacode/avo2-typings
# Searching BabylonJS/Documentation
# Searching daniel-widrick/zap2it-GuideScraping
# Searching captbaritone/grats
# Searching anydown/vscode-ganttdown
# Searching ast-grep/ast-grep
# Searching umijs/plugins
# Searching mapbox/mapbox-gl-js
# Searching DNSMadeEasy/terraform-provider-dme
# Searching danger/danger-js
# Searching soynatan/django-easy-audit
# Searching GDSC-Daejin/gdsc-dju-shared
# Searching ast-grep/eslint
# Searching detekt/detekt
# Searching sile-typesetter/sile-typesetter.github.io
# Searching nuxt-modules/i18n
# Searching cdnjs/tools
# Searching vuejs/docs
# Searching laravel-mix/laravel-mix
# Searching vueuse/vueuse
# Searching rocketseat-education/04-ignite-shop
# Searching antfu/vite-plugin-restart
# Searching denoland/vscode_deno
# Searching LaurentMazare/tch-rs
# Searching ecomfe/vue-echarts
# Searching ukontainer/sqlite-bench
# Searching inertiajs/inertia
# Searching huggingface/simulate
# Searching rocketseat-creators-program/remix-o-que-e-vantagens-e-problemas-que-resolve-2022-09-20
# Searching facebook/regenerator
# Searching aurelia/cli
# Searching wasm-tool/wasm-pack-plugin
# Searching salesforce-ux/scss-parser
# Searching Ninja-Squad/ngx-valdemort
# Searching vuejs-jp/vuefes-2018
# Searching edgedb/edgedb-js
# Searching pmndrs/zustand
# Searching Songkeys/bing-chat
# Searching GDSC-Daejin/gdsc-dju-blog-fe
# Searching dumberjs/dumber-module-loader
# Searching vuejs/vuefire
# Searching JottaF/desing-system-ignite
# Searching rocketseat-creators-program/headless-architecture-para-frontend-com-react-2022-07-14
# Searching rocketseat-creators-program/form-multistep-react-hook-form-2022-08-28
# Searching react-native-community/RNNewArchitectureApp
# Searching 0hq/WebGPT
# Searching huggingface/accelerate
# Searching depot/kysely-planetscale
# Searching intlify/vue-cli-plugin-i18n
# Searching huggingface/huggingface_hub
# Searching denoland/deno
# Searching necordjs/necord
# Searching expo/expo-cli
# Searching huggingface/spm_precompiled
# Searching vueuse/vue-demi
# Searching originjs/docs
# Searching dolmetsch/svelte-sandbox
# Searching gatsbyjs/gatsby
# Searching eggjs/egg
# Searching domaframework/doma
# Searching dmester/canvas-renderer
# Searching BuilderIO/mitosis
# Searching salesforce-ux/query-ast
# Searching GDSC-Daejin/react-todo-zustand-vite-ts
# Searching facebook/yoga
# Searching tc39/ecmarkup
# Searching denoland/deno_lint
# Searching vuejs/create-eslint-config
# Searching huggingface/large_language_model_training_playbook
# Searching Joao-Pedro-Nogueira/IgniteDesignSystem
# Searching piniajs/example-vue-3-vite
# Searching ifpeopensource/merenda-josueapp
# Searching pixelfed/pixelfed
# Searching cypress-io/cypress-example-recipes
# Searching huggingface/datasets-server
# Searching wappalyzer/wappalyzer
# Searching nuxt-modules/google-adsense
# Searching rocketseat-creators-program/responsividade-tailwindcss-reactjs-menu-hamburger
# Searching sleuth-io/terraform-provider-sleuth
# Searching vitejs/vite
# Searching bigscience-workshop/Megatron-DeepSpeed
# Searching owen-it/laravel-auditing
# Searching itsdouges/typescript-transformer-handbook
# Searching snyk/cli
# Searching system-ui/theme-ui
# Searching huggingface/diffusers
# Searching nuxt/nuxtjs.org
# Searching anydown/mangadown
# Searching koel/docs
# Searching quasarframework/quasar
# Searching nix-community/home-manager
# Searching koel/home
# Searching logto-io/logto
# Searching rescript-lang/rescript-react
# Searching anywhichway/nano-memoize
# Searching ecomfe/veui
# Searching denodrivers/redis
# Searching cloudnative-tesseract/lego
# Searching vuejs/router
# Searching web-infra-dev/rspack-website
# Searching vue-styleguidist/vue-styleguidist-example
# Searching ckeditor/ckeditor5
# Searching tailwindlabs/tailwindcss
# Searching typescript-eslint/typescript-eslint
# Searching facebookincubator/Glean
# Searching hashrock-sandbox/study-vscode-extension-webview
# Searching aws-neuron/aws-neuron-sdk
# Searching actions/setup-node
# Searching zanderchase/dagchain
# Searching RevenueCat/react-native-purchases
# Searching Brigad/eslint-no-restricted-imports-bug-repro
# Searching zenoamaro/react-quill
# Searching TanStack/tanstack.com
# Searching ca-la/bin
# Searching apostrophecms/sanitize-html
# Searching localfirstweb/localfirstweb.dev
# Searching denoland/manual
# Searching shakacode/shakapacker
# Searching DanMacedo99/to-do
# Searching vadimdemedes/ink
# Searching vuejs-translations/guidelines
# Searching anydown/anydown
# Searching huggingface/bloom-jax-inference
# Searching originjs/origin.js
# Searching vue-styleguidist/vue-live
# Searching kangax/compat-table
# Searching ONEARMY/community-platform
# Searching parsisolution/os-scroll-chain
# Searching nuxt/nuxt
# Searching doi7/doi7
# Searching borgmatic-collective/borgmatic
# Searching aws/aws-eks-best-practices
# Searching blitz-js/blitz
# Searching react-component/util
# Searching ozet-team/ozet-hybrid
# Searching rocketseat-education/nlw-esports-ignite
# Searching components-ai/css.gui
# Searching wasmerio/wasmer
# Searching dolmetsch/utils
# Searching meteor-vue/vue-meteor
# Searching ctison/graphql-codegen-golang
# Searching yarnpkg/berry
# Searching lirantal/awesome-opensource-israel
# Searching hosseinmd/prettier-plugin-jsdoc
# Searching trivago/prettier-plugin-sort-imports
# Searching apollographql/apollo-client
# Searching replayio/overboard
# Searching globalbrain/eslint-config
# Searching aws-amplify/docs
# Searching aurelia/aurelia
# Searching reactjs/react-tabs
# Searching microsoft/DeepSpeed
# Searching BuildBot42/discord-scam-links
# Searching bigscience-workshop/bigscience
# Searching mrsked/mrsk-site
# Searching AndroidStudyGroup/conferences
# Searching github-linguist/linguist
# Searching CyCraft/magnetar
# Searching reactjs/react-docgen
# Searching tailwindlabs/tailwindcss-typography
# Searching Smithay/wayland-rs
# Searching exw-md/peing-notifier
# Searching facebookarchive/bistro
# Searching viaacode/avo2-client
# Searching ca-la/react-focused-key-handler
# Searching stylelint/stylelint
# Searching craftzdog/craftzdog-homepage
# Searching snyk/user-docs
# Searching ermongroup/ddim
# Searching huggingface/doc-builder
# Searching yarnpkg/website
# Searching tailwindlabs/tailwindcss.com
# Searching netlify/build-image
# Searching hashrock-sandbox/minimal-paint-base
# Searching mdn/content
# Searching vuedx/docs
# Searching translation-gang/ru.vuejs.org
# Searching buttonwoodcx/bcx-aurelia-reorderable-repeat
# Searching svg/svgo
# Searching yang-song/score_sde_pytorch
# Searching quasarframework/cdn
# Searching tailwindlabs/heroicons.com
# Searching aurelia/documentation
# Searching diego3g/rsxp-2023
# Searching webstudio-is/immerhin
# Searching umijs/umi-next
# Searching docschina/jotai-docs-cn
# Searching zalando/restful-api-guidelines
# Searching snyk/unified-range
# Searching remix-run/remix
# Searching apache/superset
# Searching uit-community/uit-inside-transcript
# Searching statelyai/xstate
# Searching vuejs/vue-router
# Searching TanStack/router
# Searching buttons/react-github-btn
# Searching hard-kernel/awesome-elastic-stack
# Searching utrad-ical/circus-docs
# Searching dotansimha/graphql-code-generator
# Searching teambit/bit
# Searching jfromaniello/selfsigned
# Searching obsidian-userland/publish
# Searching jupyter/nbviewer
# Searching dumberjs/gulp-dumber
# Searching ca-la/nix
# Searching intlify/vue-i18n-next
# Searching vanilla-extract-css/vanilla-extract
# Searching escapemania/escapemania
# Searching ecomfe/est
# Searching reactjs/az.react.dev
# Searching huggingface/llm_training_handbook
# Searching ReactFinland/graphql-api
# Searching babel/babel
# Searching pytorch/pytorch
# Searching huggingface/api-inference-community
# Searching cloudflare/next-on-pages
# Searching vercel/next.js
# Searching huggingface/safetensors
# Searching bitwarden/contributing-docs
# Searching Automattic/Co-Authors-Plus
# Searching quasarframework/legacy-create
# Searching fi3ework/vite-plugin-checker
# Searching tricorder-observability/Starship
# Searching huggingface/blog
# Searching import-js/eslint-plugin-import
# Searching mastodon/mastodon-ansible
# Searching vuejs/jsx-vue2
# Searching expo/expo
# Searching intel/neural-compressor
# Searching vuejs-jp/home
# Searching denoland/fresh
# Searching WhatsApp/WhatsApp-Nodejs-SDK
# Searching chrisguttandin/dynamo-db-local
# Searching jestjs/jest
# Searching angular/angular-cli
# Searching volarjs/volar.js
# Searching replayio/devtools
# Searching svg/svgo-components
# Searching facebook/react-native-deprecated-modules
# Searching coreylowman/dfdx
# Searching volarjs/services
# Searching nodejs/node
# Searching gabrielbibianop/app-vendas
# Searching planttheidea/moize
# Searching anime-club/.github
# Searching Koenkk/zigbee2mqtt.io
# Searching denoland/deno_third_party
# Searching dolmetsch/langpacks-hebrew
# Searching rocketseat-education/ignite-template-reactjs-criando-um-hook-de-carrinho-de-compras
# Searching serverless-stack/kysely-data-api
# Searching denoland/deno_docker
# Searching realadvisor/react-system
# Searching rocketseat-education/ignite-nodejs-03-api-solid-nodejs
# Searching yairm210/Unciv
# Searching vue-styleguidist/vuepress-plugin-live
# Searching mlfoundations/open_clip
# Searching weis-guys/weis-guys-monorepo
# Searching globalbrain/sefirot
# Searching gaearon/overreacted.io
# Searching viaacode/avo2-components
# Searching AppIntro/AppIntro
# Searching huggingface/datasets-tagging
# Searching react-native-community/directory
# Searching huggingface/optimum
# Searching octokit/oauth-app.js
# Searching kazu728/nestjs-kysely
# Searching nodejs/undici
# Searching lvwerra/trl
# Searching cloudflare/deploy.workers.cloudflare.com
# Searching hashrock-sandbox/minroll-next
# Searching tc39/agendas
# Searching facebook/litho
# Searching owen-it/laravel-auditing-doc
# Searching sindresorhus/type-fest
# Searching terser/terser
# Searching lorenzofox3/zora
# Searching grammarly/grammarly-for-developers
# Searching pixelfed/docs
# Searching rocketseat-education/ignite-template-react-native-todos
# Searching viaacode/hetarchief-proxy
# Searching eBay/ebayui-core-react
# Searching wesbos/awesome-uses
# Searching stackblitz/ilovecodeflow.com
# Searching piniajs/example-nuxt-2
# Searching TimDettmers/bitsandbytes
# Searching ryanburgess/engineer-manager
# Searching DefinitelyTyped/DefinitelyTyped
# Searching facebook/docusaurus
# Searching openkruise/openkruise.io
# Searching huggingface/open-muse
# Searching estree/estree
# Searching rocketseat-education/explorer-lab-01
# Searching angular/angular
# Searching nestjs/docs.nestjs.com
# Searching bytecodealliance/wasmtime
# Searching wayfair/rainbow-sprinkles
# Searching facebook/jscodeshift
# Searching bigscience-workshop/model_card
# Searching vitest-dev/vitest
# Searching microsoft/VQ-Diffusion
# Searching babel/babel-loader
# Searching GoogleChrome/lighthouse-ci
# Searching GDSC-Daejin/hey-teddy-bear-web
# Searching nuxt/framework
# Searching GDSC-Daejin/gdsc-dju-websites
# Searching webpack/webpack.js.org
# Searching postcss/postcss
# Searching meteor-vue/vue-meteor-demo
# Searching rocketseat-education/ignite-template-reactjs-upload-de-imagens
# Searching koel/koel
# Searching edgedb/edgedb-docker
# Searching Totee-Side-Project/client
# Searching huggingface/widgets-server
# Searching netlify/open-api
# Searching intlify/intlify.dev
# Searching kysely-org/kysely
# Searching ast-grep/ast-grep.github.io
# Searching edgedb/edgedb-python
# Searching rocketseat-creators-program/drag-and-drop-react-dnd-kit-2023-02-18
# Searching laravel/framework
# Searching WebAssembly/tool-conventions
# Searching ivao-brasil/.github
# Searching web-platform-tests/wpt
# Searching nikolaischunk/discord-phishing-links
# Searching protomaps/OSMExpress
# Searching gdgpisa/gdgpisa.github.io
# Searching tschaub/mock-fs
# Searching vuejs/eslint-config-typescript
# Searching verdaccio/verdaccio
# Searching meteor-vue/vue-meteor-tracker
# Searching changesets/bot
# Searching statoscope/statoscope
# Searching nuxt/hackernews
# Searching getsentry/sentry-javascript
# Searching mrjones2014/smart-splits.nvim
# Searching GDSC-Daejin/.github
# Searching philschmid/transformers-deepspeed-expermiments
# Searching umijs/umi
# Searching laravel-notification-channels/expo
# Searching dprint/dprint-plugin-typescript
# Searching vue-bridge/template-monorepo
# Searching the-guild-org/website
# Searching Kotlin/kotlin-by-example
# Searching ecomfe/awesome-echarts
# Searching world-class/REPL
# Searching rocketseat-creators-program/internacionalizacao-no-react-com-i18n-e-next-js-2022-04-09
# Searching facebook/hermes
# Searching cdnjs/api-server
# Searching tc39/ecma262
# Searching cdnjs/cdnjs
# Searching bdash-app/bdash
# Searching cypress-io/cypress
# Searching fkling/astexplorer
# Searching jeremydaly/dynamodb-toolbox
# Searching simple-statistics/simple-statistics.github.com
# Searching rocketseat-education/ignite-nodejs-01-fundamentos-nodejs
# Searching denoland/rusty_v8
# Searching webpack-contrib/grunt-webpack
# Searching WebAssembly/meetings
# Searching ReactiveX/rxjs
# Searching denoland/deno_bindgen
# Searching vue-styleguidist/remark-plugin-vue-live
# Searching reactjs/ko.react.dev
# Searching koel/docker
# Searching berstend/puppeteer-extra
# Searching rocketseat-education/ignite-reactjs-03-dt-money
# Searching NixOS/nixpkgs
# Searching znckco/nestjs-unilog
# Searching viaacode/hetarchief-client
# Searching uiwjs/react-codemirror
# Searching ivao-brasil/ivao-discord-auth
# Searching vuelidate/vuelidate
# Searching rome/tools
# Searching LeapChain/Website
# Searching ivao-brasil/booking.br.ivao.aero
# Searching home-assistant/supervised-installer
# Searching citusdata/citus
# Searching uni-linux/uni
# Searching znckco/thesemetrics
# Searching occupier/ruby-node-image
# Searching anime-club/translations
# Searching renovatebot/renovate
# Searching yarnpkg/releases
# Searching Dimillian/IceCubesApp
# Searching facebookresearch/TensorComprehensions
# Searching vuejs/pinia
# Searching huggingface/datasets
# Searching vuejs/test-utils
# Searching itorr/china-ex
# Searching vuejs/language-tools
# Searching dumberjs/dumber
# Searching nuxt-community/dayjs-module
# Searching Ninja-Squad/ninja-squad.github.com
# Searching GDSC-Daejin/design-seed
# Searching type-challenges/type-challenges
# Searching tailwindlabs/tailwindcss-intellisense
# Searching vercel/swr
# Searching vuejs/regression-testing
# Searching mdn/browser-compat-data
# Searching trpc/trpc
# Searching dagster-io/airflow-migration-example
# Searching withfig/themes
# Searching quasarframework/quasar-awesome
# Searching sep2/immer-yjs
# Searching php/doc-ja
# Searching rocketseat-education/02-ignite-timer
# Searching vuejs/vitepress
# Searching vuejs/vue-issue-helper
# Searching octokit/octokit.js
# Searching vueschool/awesome-vuejs-forge
# Searching Qihoo360/wayne
# Searching musement/eslint-plugin
# Searching ossu/computer-science
# Searching magitek-telescope/greninja
# Searching edgedb/edgedb-go
# Searching rrweb-io/rrweb
# Searching badges/shields
# Searching anymaniax/orval
# Searching necordjs/necord.org
# Searching ivao-brasil/api.booking.br.ivao.aero
# Searching GDSC-Daejin/react-todo-vite-js
# Searching rome/.github
# Searching denoland/deno_std
# Searching utrad-ical/circus
# Searching storybookjs/storybook
# Searching ecomfe/light-dls
# Searching react-native-community/cli
# Searching rome/users
# Searching owen-it/laravel-auditing.com
# Searching dagster-io/dagster
# Searching volarjs/typescript-auto-import-cache
# Searching alpinejs/alpine
# Searching rocketseat-education/ignite-clean-code-desafios
# Searching ecomfe/dls-dictionary
# Searching vuejs/core
# Searching necolas/react-native-web
# Searching adapter-hub/adapter-transformers
# Searching vuejs/vue2-ssr-docs
# Searching elevenback/env-yaml-generator
# Searching fastify/fluent-json-schema
# Searching reactjs/fr.react.dev
# Searching dolmetsch/phrasebook
# Searching rack/rack
# Searching tc39/test262
# Searching gradio-app/gradio
# Searching yyx990803/launch-editor
# Searching huggingface/notebooks
# Searching sp1thas/dropboxignore
# Searching ca-la/remote-collection
# Searching Androz2091/discord-data-package-explorer
# Searching home-assistant/home-assistant.io
# Searching webstudio-is/webstudio-builder
# Searching facebook/lexical
# Searching netlify/cli
# Searching testing-library/testing-library-docs
# Searching rust-lang/rust-analyzer
# Searching umijs/qiankun
# Searching reactjs/id.react.dev
# Searching escapemania/mmomania
# Searching vitejs/docs-ja
# Searching facebook/fresco
# Searching vuedx/languagetools
# Searching originjs/webpack-to-vite
# Searching cypress-io/cypress-design
# Searching vuejs/apollo
# Searching airbnb/javascript
# Searching ifpeopensource/merenda-server
# Searching MaxGraey/wasm-check
# Searching eggjs/tegg
# Searching tailwindlabs/heroicons
# Searching rocketseat-education/ignite-reactjs-01-fundamentos-react
# Searching vitejs/vite-plugin-react
# Searching rauchg/blog
# Searching intlify/vue-i18n-extensions
# Searching automerge/automerge
# Searching rocketseat-creators-program/tabs-sincronizadas-react-router-6-2022-08-18
# Searching facebook/metro
# Searching reactjs/translations.react.dev
# Searching rocketseat-education/ignite-lab-02
# Searching edgedb/edgedb
# Searching mlco2/impact
# Searching bigscience-workshop/bloom-dechonk
# Searching ONEARMY/fixing-fashion-academy
# Searching rust-lang/rust
# Searching huggingface/tokenizers
# Searching epilot-dev/sdk-js
# Searching vitejs/vite-plugin-vue
# Searching vue-styleguidist/vue-styleguidist
# Searching facebook/relay
# Searching vitejs/docs-cn
# Searching partykit/partykit
# Searching web-infra-dev/rspack
# Searching 996-Band/996.band
# Searching whatwg/html
# Searching Tribo-Criativa/coffee-lp
# Searching anatine/zod-plugins
# Search depth: 3
# #Users to search: 2698
# Searching rita3ko
# Searching yaegassy
# Searching kojoru
# Searching mrm8488
# Searching urbanadventurer
# Searching le0nik
# Searching sandren
# Searching holtergram
# Searching regisss
# Searching anirudh1713
# Searching Pierrci
# Searching piscisaureus
# Searching blutorange
# Searching Vheissu
# Searching orta
# Searching kchibisov
# Searching YdreamW
# Searching kc0tlh
# Searching nsidnev
# Searching GeoffreyBooth
# Searching VictorSanh
# Searching YunFeng0817
# Searching vsemozhetbyt
# Searching hanefi
# Searching flakronkadriu
# Searching GugaGongadze
# Searching lobsterkatie
# Searching transiient
# Searching eratio08
# Searching rafaelfranca
# Searching digitaldesigndj
# Searching pearkes
# Searching StevenGBrown
# Searching Smashfanful
# Searching marcoscaceres
# Searching parente
# Searching fnlctrl
# Searching szymonkups
# Searching jordimas
# Searching maxim-lobanov
# Searching sylwiavargas
# Searching maxwellgerber
# Searching gustavopedroni
# Searching CloudNiner
# Searching fredboyle
# Searching babyhuangshiming
# Searching fitzgen
# Searching Uzlopak
# Searching cakiki
# Searching connorjclark
# Searching rebeccahum
# Searching clydin
# Searching arun-is
# Searching emilio
# Searching fariasmateuss
# Searching kjeremy
# Searching zh9310
# Searching dansup
# Searching esposm03
# Searching farskid
# Searching TheLarkInn
# Searching syntheticmagus
# Searching linz/linz-bde-copy
# Searching yukino-org/packages
# Searching pmndrs/react-ogl
# Searching OHDSI/DatabaseConnector
# Searching terrierteam/ir_measures
# Searching etalab/sill.etalab.gouv.fr
# Searching dresden-weekly/ansible-rails
# Searching i2p/libsam3
# Searching VueDominicana/DominicanWhoCodes
# Searching JetBrains/resharper-fsharp
# Searching appcypher/awesome-wasm-runtimes
# Searching pear/Validate
# Searching hng/tech-coops
# Searching python-semantic-release/python-semantic-release
# Searching kodecocodes/flta-materials
# Searching Stouts/Stouts.docker-run
# Searching RustMagazine/rust_magazine_2022
# Searching naver/egjs-flicking
# Searching learnyouahaskell/learnyouahaskell.github.io
# Searching workingconcept/serverless-form-handler
# Searching hyperhyperspace/p2p-chat-cli
# Searching DOCGroup/ACE_TAO
# Searching unnamed/command-flow
# Searching online-go/online-go.com
# Searching swan-io/react-ux-form
# Searching MetaMask/template-snap
# Searching gohugoio/hugoThemesSite
# Searching hyprland-community/hyprland-py
# Searching centreon/centreon-plugins
# Searching kubernetes/test-infra
# Searching CCDirectLink/CCNewGamePP
# Searching apollographql/studio-landing-page
# Searching rapid7/mettle
# Searching ourmetaverse/our-metaverse
# Searching buildkite/test_collector_elixir
# Searching tryton/stock_forecast
# Searching ASPP/2022-bilbao-testing-debugging
# Searching Decoder07/hms-callkit-demo
# Searching moonrepo/solid-blocks
# Searching massedge/wordpress-plugin-export-media-library
# Searching pajlada/serialize
# Searching foundation/foundation-sites
# Searching sdpython/code_beatrix
# Searching lunarr-app/website
# Searching darmn-js/outcome-depot
# Searching stac-extensions/forecast
# Searching front-of-house/presta
# Searching nimiq/cards
# Searching apollographql/federation-jvm
# Searching coder-mike/microvium
# Searching devcer/devcer
# Searching WsdlToPhp/PackageGenerator
# Searching game-ci/documentation
# Searching unicode-org/icu-data
# Searching c-brahms/sia-memory
# Searching MicroPad/MicroPad-Core
# Searching containerd/fifo
# Searching pestphp/pest
# Searching Innixma/kdd-2022-multimodal-automl-tutorial
# Searching go-ldap/ldap
# Searching NeuraLegion/sectester-js
# Searching liveview-native/elixirconf_chat
# Searching dotenv-org/dotenv_sinatra
# Searching superfly/fly_postgres_elixir
# Searching fossi-foundation/fossi-foundation.github.io
# Searching livegrep/livegrep
# Searching DroidKaigi/droidkaigi-feed-reader-app
# Searching SocketDev/socket-sdk-js
# Searching stream-utils/raw-body
# Searching minio/confess
# Searching okfde/proto-auth
# Searching I110IS/lab5
# Searching decentralized-identity/credential-manifest
# Searching ffaker/ffaker
# Searching veganhacktivists/5m5v-reddit
# Searching fetchai/fetchd
# Searching usi-dag/JVBench
# Searching tweag/nickel-union-contracts-paper
# Searching storyblok/custom-app-examples
# Searching ios-osushi/release-subscriptions
# Searching devind-team/xlsx_evaluate
# Searching Levminer/authme
# Searching apache/sling-org-apache-sling-jcr-repoinit
# Searching uorocketry/rocket-code-2020
# Searching ziggurat-of-ur/bundlez
# Searching postgrespro/mamonsu
# Searching discord-net/Discord.Net
# Searching matrixgpt/matrix-chatgpt-bot
# Searching cekit/cekit
# Searching brockbreacher/Join-Bot
# Searching netology-code/git-2-homeworks
# Searching Azure/DotNetty
# Searching HENNGE/arsenic
# Searching Netflix/titus-kube-common
# Searching pytorch/FBGEMM
# Searching makeomatic/deploy
# Searching qax-os/excelize
# Searching render-examples/rails-6
# Searching minecraft-linux/minecraft-imported-symbols
# Searching AnKing-Memberships/AnkiRecolor
# Searching profectus-engine/Profectus
# Searching fedora-haskell/ghc
# Searching yiisoft/yii-gii
# Searching colinodell/python-qnapstats
# Searching SteamGridDB/node-steamgriddb
# Searching phronmophobic/viscous
# Searching globalwordnet/gwadoc
# Searching Yubico/yubikit-android
# Searching multiversx/mx-sdk-go
# Searching geostyler/geostyler-style
# Searching koreanbots/api-docs
# Searching openvinotoolkit/openvino_contrib
# Searching zaki-yama-labs/linux-in-practice
# Searching slim-template/slim-rails
# Searching FrancescoXX/4c-projects
# Searching wikimedia/operations-deployment-charts
# Searching datagir/datagir-site
# Searching sindresorhus/time-span
# Searching IntelliTect/TestTools
# Searching cdktf/cdktf-provider-azurerm
# Searching PrefectHQ/prefect-great-expectations
# Searching linuxserver/docker-minetest
# Searching jech/dht
# Searching casdoor/casdoor-java-sdk
# Searching JuliaGraphics/ColorTypes.jl
# Searching easystats/parameters
# Searching VIDA-NYU/reprozip
# Searching central-perk/E-Design-Resources
# Searching doronz88/simpleelf
# Searching guardian/facia-scala-client
# Searching bminor/binutils-gdb
# Searching rancher/norman
# Searching SpyroSoft-Synergy/GazeboVideoPlayer
# Searching ktorio/ktor-documentation
# Searching EBSECan/donatemask
# Searching twigmarine/json-udp
# Searching raspberrypi/documentation
# Searching OsomePteLtd/principles
# Searching guihongwong/action
# Searching mapbox/mapbox-common-ios
# Searching FNA-NET/SDL2DroidSharp-Test
# Searching Project-Rabia/angular-deploy-demo
# Searching bitcraze/crazyflie-clients-python
# Searching nerc-project/nerc-docs
# Searching Autoratch/Thailand-Olympiad-in-Informatics
# Searching Forceu/barcodebuddy-homeassistant
# Searching EPLibrary/esc-bug
# Searching Cereal2nd/velbus-aio
# Searching TFNS/CTFNote
# Searching linuxmint/mintwelcome
# Searching gabrielcnr/pytest-datadir
# Searching mozilla/legal-docs
# Searching baleada/vue-composition
# Searching unlock-protocol/discord-integration
# Searching manjaro/manjaro-docker
# Searching ColinIanKing/stress-ng
# Searching Milkdown/milkdown
# Searching getsentry/django-db-log-demo
# Searching scala/scala
# Searching cmyr/cargo-instruments
# Searching sayedihashimi/template-sample
# Searching symfony/security-core
# Searching flarum/tags
# Searching misenhower/splatoon3.ink
# Searching nthparty/b3d
# Searching jenkinsci/analysis-pom-plugin
# Searching CodingPlatelets/webdesign
# Searching KyoriPowered/adventure
# Searching gradle/gradle-profiler
# Searching contentpal/contentpal
# Searching zeldaret/mm
# Searching zopefoundation/BTrees
# Searching zmwangx/rust-ffmpeg-sys
# Searching exmbuild/exm-cli
# Searching PixarAnimationStudios/USD
# Searching osm-fr/osmose-fr-opendata-scripts
# Searching lgbtq-technology/lgbtq-technology.github.io
# Searching drogue-iot/drogue-esp8266
# Searching solely-archive/sol-bot
# Searching Zverik/every_door
# Searching lefthandz-githubtraining/class-repo-apr-13-14
# Searching radicle-dev/radicle-client-services
# Searching apache/maven-doxia
# Searching yingku/nn-verification
# Searching LIKS/bachelor_thesis_template_vu_mif_se
# Searching jetbrains-academy/Testing-Course
# Searching freebsd/freebsd-quarterly
# Searching lunarr-app/vlc-player
# Searching OP2/PyOP2
# Searching UniBuc-DITC/openproject-deployment-config
# Searching UO-CIS322/project-4
# Searching ethereum/staking-deposit-cli
# Searching nodecraft/spawnpoint-express
# Searching pixijs/animate-extension
# Searching SalesCreations/site-salescreations
# Searching open-component-model/ocm
# Searching TheLabbingProject/pylabber
# Searching ros2/rosidl
# Searching twilio/twilio-python
# Searching hashicorp/go-immutable-radix
# Searching MathKeyboardEngine/MathKeyboardEngine
# Searching onmyway133/awesome-machine-learning
# Searching workingconcept/lever-craft-plugin
# Searching fp-ts/core
# Searching chunheisiu/parrt-rules
# Searching traPtitech/game3-wordpress
# Searching matthiaaas/express-file-routing
# Searching azurystudio/cheetah
# Searching videomark/videomark.webdino.org
# Searching spring-projects/spring-ws
# Searching ianthehenry/judge
# Searching PowerDNS/pdns
# Searching thesayyn/protoc-gen-ts
# Searching bazelbuild/apple_support
# Searching happo/docs
# Searching blessanm86/tweet-to-html
# Searching coverallsapp/github-action
# Searching haskell/unix
# Searching komoot/photon
# Searching WebAssembly/wasi-logging
# Searching teal-finance/quidpy
# Searching Jack000/glid-3-xl-stable
# Searching TechAndCoffee/techandcoffee-site
# Searching 11ty/eleventy-base-blog
# Searching pages-hugoconf-2022/refactored-octo-journey
# Searching RI-imaging/ODTbrain
# Searching chronotope/chrono-tz
# Searching opengraphninja/react
# Searching jessesquires/TIL
# Searching zhayujie/chatgpt-on-wechat
# Searching pgq/pgq
# Searching robinweser/kilvin
# Searching ArduPilot/SiK
# Searching worldcoin/world-id-debug-tools
# Searching aja-video/ntv2
# Searching javascript-obfuscator/javascript-obfuscator
# Searching saas-js/saas-ui
# Searching neogeny/TatSu
# Searching rakaly/jomini
# Searching vusion/lcap-usage-demo
# Searching kode-keder/boilerplate
# Searching MicrosoftLearning/PL-400_Microsoft-Power-Platform-Developer
# Searching cloudquery/cq-provider-sdk
# Searching MusaAkyuz/Computer-Science-Resources
# Searching TaylorT52/ContourDetection
# Searching GirlsFromPanema/Electra
# Searching yobgob/too-many-hooks
# Searching RobersonLab/wustl_ris_docker_image_builds
# Searching chaijs/guidelines
# Searching hashicorp/vault-secrets-operator
# Searching manosim/remix-auth-facebook
# Searching commonform/commonform.org
# Searching opendevise/asciidoc-samples
# Searching Zenika/scan-and-give
# Searching commonform/commonform-flatten
# Searching facebook/homebrew-fb
# Searching Sisoll/java-paratice
# Searching Azure-Samples/storage-dotnet-circuit-breaker-ha-ra-grs
# Searching spack/spack-tutorial
# Searching fabianboesiger/ftx
# Searching membrane-io/homebrew-mctl
# Searching elementary-data/elementary
# Searching ArticaDev/impulsiona-seguidores
# Searching metal3-io/baremetal-operator
# Searching DFE-Digital/slack-incident-bot
# Searching Flag-Nor-Fail/.github
# Searching oracle-devrel/picluster
# Searching sdsykes/fastimage
# Searching defold/extension-camera
# Searching Fabian-Schmidt/esphome-victron_ble
# Searching arviz-devs/arviz-project
# Searching hiberbee/github-action-kops
# Searching ash-project/ash_phoenix
# Searching tastyigniter/docs
# Searching redhat-developer/devspaces-chectl
# Searching TypiCMS/Core
# Searching Kotlin/kotlinx.collections.immutable
# Searching redwoodjs/playground-auth
# Searching bixbyjs/bixby
# Searching momi-foundation-coding/kemboi-code-academy
# Searching palkan/action_policy
# Searching apollosolutions/router-aws-sign
# Searching premkit/premkit
# Searching wbolster/emacs-python-black
# Searching Project-Mudrika/Mudrika-API
# Searching jpmorganchase/modular
# Searching keith/rules_apple_linker
# Searching nikis05/derive-visitor
# Searching hpcaitech/SkyComputing
# Searching words/stemmer
# Searching jay-babu/mason-null-ls.nvim
# Searching lesleyxyz/python-homewizard-kitchen
# Searching enjoy-digital/liteeth
# Searching invirtu-libraries/Invirtu-Javascript-API
# Searching spring-guides/gs-accessing-data-neo4j
# Searching OpenATBP/OpenATBP
# Searching octokit-fixture-org/tmp-scenario-branch-protection-20220722042609743-ezhtx
# Searching zaver-io/zaver-php-sdk
# Searching pygfx/wgpu-py
# Searching twitterjs/website
# Searching LucasDower/ObjToSchematic
# Searching PrairieLearn/PrairieGrader
# Searching tighten/jigsaw-blog-template
# Searching digineo/sisimai-web
# Searching wikimedia/translatewiki
# Searching craftcms/store-hours
# Searching code-423n4/2023-01-biconomy
# Searching wundergraph/wunderctl
# Searching tj/node-cookie-signature
# Searching lighttransport/nanostl
# Searching yquake2/xatrix
# Searching devsonket/devsonket.github.io
# Searching MillCloud/glossary-json
# Searching caddyserver/transform-encoder
# Searching dimdenGD/discord-oled-theme
# Searching Floogen/Stardrop
# Searching mirahi-io/rn-template
# Searching timewarpinc/actions
# Searching hyperium/hyper-util
# Searching MetaMask/phishing-warning
# Searching codestates-seb/seb43_pre_013
# Searching sysprog21/lab0-c
# Searching jacobparis/remix-nx-fly
# Searching Tomiinek/MultiWOZ_Evaluation
# Searching demoth/cpucat
# Searching ipfs/go-cid
# Searching NangoHQ/nango
# Searching fly-apps/global-rails
# Searching Lienol/openwrt
# Searching MechanicalSoup/MechanicalSoup
# Searching spdx/meetings
# Searching celo-org/celocli
# Searching localgovdrupal/localgov_alert_banner
# Searching nablarch/nablarch-single-module-archetype
# Searching vapor/toolbox
# Searching pokt-foundation/charts
# Searching beyonk-adventures/svelte-carousel
# Searching terraform-google-modules/terraform-google-project-factory
# Searching LightningCreations/lc-binutils
# Searching serene-dev/snake-py
# Searching hucsmn/qbsdiff
# Searching nix-community/infra
# Searching soulwing/iso3166-scraper
# Searching gradlex-org/gradlex-org.github.io
# Searching google-github-actions/auth
# Searching openvinotoolkit/openvino_notebooks
# Searching apostrophecms/a3-docs
# Searching thinkst/canarytokens
# Searching transcom/alb-to-cloudwatch-lambda
# Searching Qiskit-Partners/mapomatic
# Searching Elibaap/krazyshop
# Searching themanaworld/upptime
# Searching scrive/consumers
# Searching execut4ble/realnames
# Searching pipeline-components/snyk
# Searching mmperf/mmperf
# Searching crawl/crawl-glyphs
# Searching DTStack/create-molecule
# Searching freeCodeCamp/chinese
# Searching chartjs/awesome
# Searching huggingface/rlhf-interface
# Searching whyrusleeping/ipfs-key
# Searching flutter/samples
# Searching idoknow/stumap-docs
# Searching researchbase/helm-charts
# Searching getsentry/symbolicator
# Searching microsoft/opensource-management-portal
# Searching shower/material
# Searching siemens/kas
# Searching canvg/canvg
# Searching digital-craftsman-de/ids
# Searching Roblox/rhysd-github-action-benchmark
# Searching ascii-boxes/boxes
# Searching nostr-protocol/nostr
# Searching FruitieX/add-bot-rs
# Searching downshift-js/downshift-docs
# Searching SAP/ui5-project
# Searching rsl/stringex
# Searching rutkinj/quotes
# Searching apache/maven-wrapper
# Searching caido/caido
# Searching elastic/elasticsearch-ruby
# Searching HazyResearch/fly
# Searching rust-secure-code/cargo-supply-chain
# Searching SumoLogic/terraform-provider-sumologic
# Searching CodyConck/die-db
# Searching giantswarm/architect
# Searching akshaysom/spring-aspectj
# Searching fusebit/demo-task-app
# Searching transmission/transmission.github.io
# Searching jsdocs-io/web
# Searching fly-apps/terraformed-machines
# Searching Bright-Computing/bright-installer-ansible
# Searching standardebooks/agatha-christie_the-murder-of-roger-ackroyd
# Searching input-output-hk/cardano-db-sync
# Searching dropbox/pb-jelly
# Searching AthenZ/athenz
# Searching deus-labs/cw-contracts
# Searching wuba/taro-playground
# Searching WildGums/Orc.Sort
# Searching jonathantneal/convert-colors
# Searching COSCUP/2022
# Searching sketch-community/cocoascript-types
# Searching 0oAstro/dim.lua
# Searching NervJS/taro-native-shell
# Searching FlandreDaisuki/rollup-plugin-userscript-metablock
# Searching kubernetes-sigs/kwok
# Searching tsg/demo7
# Searching select2/select2
# Searching communi/communi-desktop
# Searching GameGodS3/DropPoint
# Searching javascript-tutorial/ja.javascript.info
# Searching rancavil/hadoop-single-node-cluster
# Searching Flagsmith/react-native-performance-monitor
# Searching ge-high-assurance/RACK
# Searching codinasion-archive/codinasion-data
# Searching plugdata-team/plugdata
# Searching MicrosoftDocs/live-share
# Searching WeblateOrg/wlc
# Searching vmware-tanzu/velero-plugin-example
# Searching oasis-tcs/csaf
# Searching netdata/charts
# Searching ef4/ember-head
# Searching tumaer/SciML22-23
# Searching DhruvDh/umm
# Searching odroe/prisma-dmmf
# Searching krille-chan/fluffychat-snap
# Searching pb33f/libopenapi
# Searching skyra-project/tags
# Searching cilium/json-mock
# Searching google/BIG-bench
# Searching PACKED-vzw/digitale-strategie
# Searching pingcap-inc/tidb-community-ui
# Searching conda-forge/admin-requests
# Searching samatechtw/android-ble
# Searching cucumber/common
# Searching markvanderloo/tinytest
# Searching glorand/laravel-model-settings
# Searching FreeFeed/freefeed-react-client
# Searching etcd-io/raft
# Searching dietercoopman/mailspfchecker
# Searching UniversalDevicesInc/pgc_k8s_fluentd
# Searching vim-denops/deno-vim-channel-command
# Searching conan-io/docs
# Searching google/grinder.dart
# Searching noon-happen/.github
# Searching signalfx/signalfx-java
# Searching uber-go/multierr
# Searching dayjs/dayjs-website
# Searching houseabsolute/Log-Dispatch
# Searching nextcloud/nextcloud-config-converter
# Searching pnpm/meta-updater
# Searching intel/ipu6-drivers
# Searching HtmlUnit/htmlunit-cssparser
# Searching Caballero-Arepa/Community-Maps
# Searching discord-modifications/dark-discord
# Searching auroraextensions/docs
# Searching gap-packages/fr
# Searching logicmonitor/lm-data-sdk-go

# %%
g.rate_limiting[0]
# Out:
# 3591

# %%
pd.DataFrame.from_records(fetched_users_data).to_csv('./output/users.csv')
pd.DataFrame.from_records(fetched_repos_data).to_csv('./output/repos.csv')
pd.DataFrame.from_records(fetched_contributions_data).to_csv('./output/contributions.csv')

# %%
query = gql(
    """
    query getUserConnections($login: String!)
    {
        user(login: $login) {
            name
            repositoriesContributedTo(first: 1, privacy: PUBLIC) {
                nodes {
                    name
                    refs(refPrefix: \"refs/heads/\", orderBy: {direction: DESC, field: TAG_COMMIT_DATE}, first: 100) {
                        edges {
                            node {
                                ... on Ref {
                                    target {
                                        ... on Commit {
                                            history {
                                                totalCount
                                                edges{
                                                    node{
                                                        ... on Commit{
                                                            committer {
                                                                user {
                                                                    login
                                                                }
                                                            }
                                                            committedDate
                                                        }
                                                    }
                                                }
                                            }
                                        }
                                    }
                                }
                            }
                        }
                    }
                }
            }
        }
    }
    """
)


res = await client.execute_async(query, {"login": top_users['login'][0]})
res
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File /opt/homebrew/Caskroom/miniconda/base/envs/data-collection/lib/python3.11/site-packages/aiohttp/connector.py:1152, in TCPConnector._create_direct_connection(self, req, traces, timeout, client_error)
#    1148 try:
#    1149     # Cancelling this lookup should not cancel the underlying lookup
#    1150     #  or else the cancel event will get broadcast to all the waiters
#    1151     #  across all connections.
# -> 1152     hosts = await asyncio.shield(host_resolved)
#    1153 except asyncio.CancelledError:
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/data-collection/lib/python3.11/site-packages/aiohttp/connector.py:874, in TCPConnector._resolve_host(self, host, port, traces)
#     872         await trace.send_dns_resolvehost_start(host)
# --> 874 addrs = await self._resolver.resolve(host, port, family=self._family)
#     875 if traces:
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/data-collection/lib/python3.11/site-packages/aiohttp/resolver.py:33, in ThreadedResolver.resolve(self, hostname, port, family)
#      30 async def resolve(
#      31     self, hostname: str, port: int = 0, family: int = socket.AF_INET
#      32 ) -> List[Dict[str, Any]]:
# ---> 33     infos = await self._loop.getaddrinfo(
#      34         hostname,
#      35         port,
#      36         type=socket.SOCK_STREAM,
#      37         family=family,
#      38         flags=socket.AI_ADDRCONFIG,
#      39     )
#      41     hosts = []
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/data-collection/lib/python3.11/asyncio/base_events.py:867, in BaseEventLoop.getaddrinfo(self, host, port, family, type, proto, flags)
#     865     getaddr_func = socket.getaddrinfo
# --> 867 return await self.run_in_executor(
#     868     None, getaddr_func, host, port, family, type, proto, flags)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/data-collection/lib/python3.11/concurrent/futures/thread.py:58, in _WorkItem.run(self)
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/data-collection/lib/python3.11/socket.py:962, in getaddrinfo(host, port, family, type, proto, flags)
#     961 addrlist = []
# --> 962 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     963     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 8] nodename nor servname provided, or not known
#
# The above exception was the direct cause of the following exception:
#
# ClientConnectorError                      Traceback (most recent call last)
# Cell In[7], line 45
#       1 query = gql(
#       2     """
#       3     query getUserConnections($login: String!)
#    (...)
#      41     """
#      42 )
# ---> 45 res = await client.execute_async(query, {"login": top_users['login'][0]})
#      46 res
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/data-collection/lib/python3.11/site-packages/gql/client.py:285, in Client.execute_async(self, document, variable_values, operation_name, serialize_variables, parse_result, get_execution_result, **kwargs)
#     283 """:meta private:"""
#     284 async with self as session:
# --> 285     return await session.execute(
#     286         document,
#     287         variable_values=variable_values,
#     288         operation_name=operation_name,
#     289         serialize_variables=serialize_variables,
#     290         parse_result=parse_result,
#     291         get_execution_result=get_execution_result,
#     292         **kwargs,
#     293     )
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/data-collection/lib/python3.11/site-packages/gql/client.py:1220, in AsyncClientSession.execute(self, document, variable_values, operation_name, serialize_variables, parse_result, get_execution_result, **kwargs)
#    1200 """Coroutine to execute the provided document AST asynchronously using
#    1201 the async transport.
#    1202
#    (...)
#    1216
#    1217 The extra arguments are passed to the transport execute method."""
#    1219 # Validate and execute on the transport
# -> 1220 result = await self._execute(
#    1221     document,
#    1222     variable_values=variable_values,
#    1223     operation_name=operation_name,
#    1224     serialize_variables=serialize_variables,
#    1225     parse_result=parse_result,
#    1226     **kwargs,
#    1227 )
#    1229 # Raise an error if an error is returned in the ExecutionResult object
#    1230 if result.errors:
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/data-collection/lib/python3.11/site-packages/gql/client.py:1126, in AsyncClientSession._execute(self, document, variable_values, operation_name, serialize_variables, parse_result, **kwargs)
#    1118             variable_values = serialize_variable_values(
#    1119                 self.client.schema,
#    1120                 document,
#    1121                 variable_values,
#    1122                 operation_name=operation_name,
#    1123             )
#    1125 # Execute the query with the transport with a timeout
# -> 1126 result = await asyncio.wait_for(
#    1127     self.transport.execute(
#    1128         document,
#    1129         variable_values=variable_values,
#    1130         operation_name=operation_name,
#    1131         **kwargs,
#    1132     ),
#    1133     self.client.execute_timeout,
#    1134 )
#    1136 # Unserialize the result if requested
#    1137 if self.client.schema:
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/data-collection/lib/python3.11/asyncio/tasks.py:479, in wait_for(fut, timeout)
#     476         raise
#     478 if fut.done():
# --> 479     return fut.result()
#     480 else:
#     481     fut.remove_done_callback(cb)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/data-collection/lib/python3.11/site-packages/gql/transport/aiohttp.py:296, in AIOHTTPTransport.execute(self, document, variable_values, operation_name, extra_args, upload_files)
#     293 if self.session is None:
#     294     raise TransportClosed("Transport is not connected")
# --> 296 async with self.session.post(self.url, ssl=self.ssl, **post_args) as resp:
#     298     async def raise_response_error(resp: aiohttp.ClientResponse, reason: str):
#     299         # We raise a TransportServerError if the status code is 400 or higher
#     300         # We raise a TransportProtocolError in the other cases
#     302         try:
#     303             # Raise a ClientResponseError if response status is 400 or higher
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/data-collection/lib/python3.11/site-packages/aiohttp/client.py:1141, in _BaseRequestContextManager.__aenter__(self)
#    1140 async def __aenter__(self) -> _RetType:
# -> 1141     self._resp = await self._coro
#    1142     return self._resp
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/data-collection/lib/python3.11/site-packages/aiohttp/client.py:536, in ClientSession._request(self, method, str_or_url, params, data, json, cookies, headers, skip_auto_headers, auth, allow_redirects, max_redirects, compress, chunked, expect100, raise_for_status, read_until_eof, proxy, proxy_auth, timeout, verify_ssl, fingerprint, ssl_context, ssl, proxy_headers, trace_request_ctx, read_bufsize)
#     534     async with ceil_timeout(real_timeout.connect):
#     535         assert self._connector is not None
# --> 536         conn = await self._connector.connect(
#     537             req, traces=traces, timeout=real_timeout
#     538         )
#     539 except asyncio.TimeoutError as exc:
#     540     raise ServerTimeoutError(
#     541         "Connection timeout " "to host {}".format(url)
#     542     ) from exc
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/data-collection/lib/python3.11/site-packages/aiohttp/connector.py:540, in BaseConnector.connect(self, req, traces, timeout)
#     537         await trace.send_connection_create_start()
#     539 try:
# --> 540     proto = await self._create_connection(req, traces, timeout)
#     541     if self._closed:
#     542         proto.close()
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/data-collection/lib/python3.11/site-packages/aiohttp/connector.py:901, in TCPConnector._create_connection(self, req, traces, timeout)
#     899     _, proto = await self._create_proxy_connection(req, traces, timeout)
#     900 else:
# --> 901     _, proto = await self._create_direct_connection(req, traces, timeout)
#     903 return proto
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/data-collection/lib/python3.11/site-packages/aiohttp/connector.py:1166, in TCPConnector._create_direct_connection(self, req, traces, timeout, client_error)
#    1163         raise
#    1164     # in case of proxy it is not ClientProxyConnectionError
#    1165     # it is problem of resolving proxy ip itself
# -> 1166     raise ClientConnectorError(req.connection_key, exc) from exc
#    1168 last_exc: Optional[Exception] = None
#    1170 for hinfo in hosts:
#
# ClientConnectorError: Cannot connect to host api.github.com:443 ssl:False [nodename nor servname provided, or not known]
